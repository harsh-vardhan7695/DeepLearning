# %%
from keras.models import Model
from keras.layers import *

# %%
model=Model()

# %%
#define two sets of inputs
inputA=Input(shape=(32,))
inputB=Input(shape=(128,))

# %%
#the first branch operates on the first input
x=Dense(8,activation='relu')(inputA)
x1=Dense(4,activation='relu')(x)

# %%
#the second branch operates on the second input
y=Dense(62,activation='relu')(inputB)
y1=Dense(32,activation='relu')(y)
y2=Dense(4,activation='relu')(y1)

# %%
#combinming the  output of the two branches

combined=concatenate([x1,y2])

# %%
#apply a FC layer and then a regression prediction on the combined outputs
z=Dense(2,activation='relu')(combined)
z1=Dense(1,activation='linear')(z)

# %%
model=Model(inputs=[inputA,inputB],outputs=z)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 128)]                0         []
#
#  input_1 (InputLayer)        [(None, 32)]                 0         []
#
#  dense_2 (Dense)             (None, 62)                   7998      ['input_2[0][0]']
#
#  dense (Dense)               (None, 8)                    264       ['input_1[0][0]']
#
#  dense_3 (Dense)             (None, 32)                   2016      ['dense_2[0][0]']
#
#  dense_1 (Dense)             (None, 4)                    36        ['dense[0][0]']
#
#  dense_4 (Dense)             (None, 4)                    132       ['dense_3[0][0]']
#
#  concatenate (Concatenate)   (None, 8)                    0         ['dense_1[0][0]',
#                                                                      'dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 2)                    18        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 10464 (40.88 KB)
# Trainable params: 10464 (40.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model,show_shapes=True)
